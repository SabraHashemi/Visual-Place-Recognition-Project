# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
#!git clone --recursive https://github.com/FarInHeight/Visual-Place-Recognition-Project.git
# !git clone --recursive -b devel1 https://github.com/SabraHashemi/Visual-Place-Recognition-Project.git

# %% [markdown]
# ## Install dependencies

# %%
# %cd Visual-Place-Recognition-Project/image-matching-models
# !pip install -e .[all]

# %%
# !pip install faiss-cpu
# !pip install wandb

# %% [markdown]
# ## Setup Weights & Biases (Optional)
#
# If you want to log your experiments to Weights & Biases, you can login here. The VPR evaluation will automatically log metrics if wandb is installed.

# %%
# Login to wandb (optional - uncomment if you want to use wandb)
# !wandb login

# %% [markdown]
# ## Download Datasets

# %%
# %cd ..
# !python download_datasets.py

# %%
# !wandb login

# %% [markdown]
# ## Run your First VPR Evaluation
#
# **Note:** Metrics will be automatically logged to Weights & Biases if wandb is installed and logged in. Check your wandb dashboard to see recall metrics, hyperparameters, and experiment details.

# %%
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir log_dir \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder '<path-to-database-folder>' \
--queries_folder '<path-to-queries-folder>' \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir log_dir \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder 'data/tokyo_xs/test/database' \
--queries_folder 'data/tokyo_xs/test/queries' \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty \
--device 'cpu'

# %% [markdown]
# ## Run Image Matching on Retrieval Results

# %%
# !python match_queries_preds.py \
--preds-dir '<path-to-predictions-folder>' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ## Check Re-ranking Performance

# %%
# !python reranking.py \
--preds-dir '<path-to-predictions-folder>' \
--inliers-dir '<path-to-inliers-folder>' \
--num-preds 20 \
--recall-values 1 5 10 20

# %% [markdown]
# ## Perform Uncertainty Evalutation

# %%
# !python -m vpr_uncertainty.eval \
--preds-dir '<path-to-predictions-folder>' \
--inliers-dir '<path-to-inliers-folder>' \
--z-data-path '<path-to-z-data-file>'

# %%
# CosPlace with ResNet50
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir log_dir \
--method=cosplace --backbone=ResNet50 --descriptors_dimension=2048 \
--image_size 512 512 \
--database_folder 'data/tokyo_xs/test/database' \
--queries_folder 'data/tokyo_xs/test/queries' \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# !python match_queries_preds.py \
--preds-dir 'logs/log_dir/2025-11-15_15-10-19/preds' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %%
# !python reranking.py \
--preds-dir 'logs/log_dir/2025-11-15_15-10-19/preds' \
--inliers-dir 'logs/log_dir/2025-11-15_15-10-19/preds_superpoint-lg' \
--num-preds 20 \
--recall-values 1 5 10 20

# %%
# NetVLAD
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir log_dir \
--method=netvlad --backbone=VGG16 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder 'data/tokyo_xs/test/database' \
--queries_folder 'data/tokyo_xs/test/queries' \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty

# %%
# !python match_queries_preds.py \
--preds-dir 'logs/log_dir/2025-11-15_15-39-45/preds' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %%
# !python reranking.py \
--preds-dir 'logs/log_dir/2025-11-15_15-39-45/preds' \
--inliers-dir 'logs/log_dir/2025-11-15_15-39-45/preds_superpoint-lg' \
--num-preds 20 \
--recall-values 1 5 10 20

# %%
# MixVPR
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir log_dir \
--method=mixvpr --backbone=ResNet50 --descriptors_dimension=4096 \
--image_size 512 512 \
--database_folder 'data/tokyo_xs/test/database' \
--queries_folder 'data/tokyo_xs/test/queries' \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty
